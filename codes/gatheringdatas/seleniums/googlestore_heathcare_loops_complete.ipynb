# %%
from selenium import webdriver

# %%
# open chrome browser
browser = webdriver.Chrome(executable_path='../../../../chromedriver.exe')

# %%
# url in address window
browser.get('https://play.google.com/store/search?q=%ED%97%AC%EC%8A%A4%EC%BC%80%EC%96%B4%EC%95%B1&c=apps&hl=ko-KR')

# %%
browser.implicitly_wait(10)

# %%
import pandas as pd
import pymongo as mg

# %%
# 서비스 앱에 대한 리스트
click_path = 'section > div > div > div > div'
company_list = browser.find_elements_by_css_selector(click_path)

len(company_list)

for company in company_list:
    company.click()
    time.sleep(2)

    # 서비스 앱에 대한 정보 가져오기
    try:
        service_name = browser.find_element_by_css_selector('div > h1 > span').text
    except :
        service_name = str()
    try :    
        company_name = browser.find_element_by_css_selector('div.Il7kR > div > div > div > a > span').text
    except : 
        company_name = str()
    try :    
        app_information = browser.find_element_by_css_selector('div:nth-child(1) > c-wiz:nth-child(2) > div > section > div').text
    except :
        app_information = str()

    # [service_name, company_name, app_information]

    # 댓글 팝업 띄우기(해당 리뷰 없을 시 대비한 방어 코드 작성 필요)
    review_flag = True
    try :
        browser.find_element_by_xpath('//*/div/div/button/*[contains(text(), "리뷰")]').click()    
    except :
        review_flag = False
    
    # 회사 서비스에 대한 전체 리뷰 가져오기
    serviceapp_columns_name = ['service_name', 'content', 'date', 'stars']
    reviews_list = list()
    if review_flag :
        reviews_bundle = browser.find_elements_by_css_selector('div.fysCi > div > div:nth-child(2) > div')
        len(reviews_bundle)    

        for review_bundle in reviews_bundle:
            content = review_bundle.find_element_by_css_selector('div.h3YV2d').text
            date = review_bundle.find_element_by_css_selector('header > div.Jx4nYe > span').text
            stars = review_bundle.find_element_by_css_selector('header > div.Jx4nYe > div').get_attribute('aria-label')
            review_list = [service_name, content, date, stars]
            reviews_list.append(review_list)  # 리뷰에 대한 모든 것(특정 회사 서비스에 대한)

        browser.back() # 팝업 닫기
        # 저장 위한 작업
        df_reviews = pd.DataFrame(data=reviews_list, columns=serviceapp_columns_name)

    print('service_name : {}, review count : {}'.format(service_name, len(reviews_list)))
    browser.back() # 리스트로 돌아가기
    time.sleep(3)
# Out:
# service_name : Samsung Health(삼성 헬스), review count : 40
# service_name : NH헬스케어, review count : 40
# service_name : 케어헬스, review count : 17
# service_name : 기업용 디지털 헬스케어 삼성화재 애니핏 프로(PRO), review count : 7
# service_name : 애니핏 플러스 나에게 핏한 건강관리, review count : 40
# service_name : SK VIEW 헬스케어, review count : 2
# service_name : 헬스케치-건강검진 기반 건강지표/위험도 분석,맞춤 헬스, review count : 14
# service_name : 헬스케어 건강관리서비스, review count : 1
# service_name : PT쌤 - 운동 헬스 체중관리 체력테스트 홈트 기록, review count : 24
# service_name : 플릭 - 운동일지, 운동기록, 운동일기, 운동루틴, review count : 40
# service_name : Health4U, review count : 40
# service_name : 플랜핏 - 헬스 홈트 운동 루틴 추천과 피트니스 기록, review count : 40
# service_name : 현대해상 메디케어, review count : 40
# service_name : 삼성생명 S-헬스케어, review count : 25
# service_name : 운동닥터 - 헬스장 PT, 필라테스 찾기 필수 앱, review count : 40
# service_name : 케어포미, review count : 28
# service_name : 헬스 플랫폼, review count : 40
# service_name : 티티케어 – 나의 멍냥육아 파트너, review count : 40
# service_name : 온닥터, review count : 40
# service_name : 빅케어, review count : 35
# service_name : 채움건강, review count : 40
# service_name : 오케어, review count : 40
# service_name : 케어네이션 - 일감 찾기, 간병인, 동행인, 요양보호사, review count : 40
# service_name : HiNT: Healthcare iN Technology, review count : 7
# service_name : 굿헬스케어 - 당뇨예방을 위한 건강관리서비스, review count : 0
# service_name : 어떠케어 - 내 몸이 궁금할 때, review count : 40
# service_name : 운동코치 짐데이, review count : 40
# service_name : Health Keeper, review count : 40
# service_name : 헬스 iN - 헬스인의 필수 앱, review count : 0
# service_name : Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱, review count : 40

# %%
reviews_list
# Out:
# [['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   "다양한 분석자료가 맘에 들고, 섬세하게 측정 잘 됩니다. 좋은 점도 많지만 단점이 많습니다. 1. 외국인이 작성했는지, 번역기를 돌렸는지 틀린 글씨나 틀린 문법이 많습니다. 고쳐주세요. 칼로리에도 단위에 'k(킬로)'를 붙여야 맞습니다. 2. 운동 프로그램(걷기)을 내 맘대로 변경할 수 있었으면 좋겠습니다. 3. 지도가 굉장히 질이 떨어집니다. 건물이나 길이 표시되지 않아 불편해요. 4. GPS 오류가 많습니다. GPS가 아무데나 쭉쭉 뻗어나가서 거리 정확도가 많이 떨어집니다. 5. 올린 글을 수정, 삭제할 수 있게 해 주세요. 6. 최근 업데이트 이후 앱이 다운되는 현상이 많이 발생합니다. 오류 잡아주세요.",
#   '2019년 12월 28일',
#   '별표 5개 만점에 4개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '만보기 처음에는 신기해서 정기결제해서 사용했는데... 겨울이 찾아와서 걷기가 힘들어졌네요. 그래도 꾸준히 켜놓고 사용중입니다. 이전에는 1천걸음도 안걸었는데 하루에 몇걸음 걸었는지 확인할 수 있어서 좋습니다. 만보기와 미밴드가 호환 안돼서 아쉽지만 얼마전에 미밴드도 구입했습니다. 변화의 계기는 만보기앱으로 시작됐습니다.',
#   '2019년 12월 10일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '자동결제 어떻게 취소하냐구요 정확히 홈페이지 어디로 연락하라는건지 이메일로 연락하라는건지 제대로 게시하지도 않고. 무료체험 신청했는데 이후에 자동으로 결제된다고 뭐 제대로 확인 할 새도 없이 빠르게 팝업 뜨고 없어지더니 지금까지 매달 2500원씩 5000원나감 그리고 결제 중단한다는 버튼도 아무리 찾아봐도 없음. 개사기꾼임 빨리 내 결제 취소하라고요.',
#   '2018년 11월 17일',
#   '별표 5개 만점에 1개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '걷는걸 좋아하는 사람입니다^^ 제가 걷는 코스가 몇키로가 되는지 궁금해서 gps 지도 표시가 되는 만보기 앱을 찾고 있었는데 혹시나 하는 마음에 깔아서 2회 정도 써본 결과 정확도 높은 편입니다^^ 등산로 코스 표기는 어떠한지 모르겠지만 지도에 내가 걸어온 길을 어느정도 정확하게 표기가 되는게 신기 했습니다^^ 스마트워치 사기 전까지만 쓸 예정이지만 생각보다 괜찮고 정확도가 있다고 설명 드리고 싶습니다^^',
#   '2019년 3월 12일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   "먼저 다운로드 받은 다른 앱에서는 8천보인데 이 앱에서는 9천보였어요. 다른 앱이 놓친 도보수를 이 앱은 놓치지 않는거 같아서...이전 만보기앱은 삭제했어요. ^^ 근데... 날짜가 상단 왼쪽에 있던게 왜 오른쪽 캘린더 표시로 '일'하나만 표시되는지...년월일 모두 표시됬으면 좋겠어요~",
#   '2021년 6월 5일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '나는 결제한적이 없는데 자동결제가 되었어요.나는 무료라고 해서 사용하고 있었습니다. 그런데 어제 11월 18일 오후 6시쯤에 5500원이 결제되었어요. 나는 그 시간에 결제한적이 없습니다. 48시간이내에 환불 신청하면 환불된다고 하더니 환불도 않된다고 하고 완전 최악입니다.쓰레기 입니다..큰돈은 아니더라도 기분이 너무 나쁩니다. 결제된다는 말도 없이 나의 계좌에서 돈을 빼갔습니다.5500원 돌려주세요.',
#   '2022년 11월 19일',
#   '별표 5개 만점에 1개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '헬스 신기록을 갱신했을때 갱신했다고 축하효과음이라도 나왔으면 좋겠네요 휴대폰이 진동모드가 아닐때만 말이죠 전 보통사람들과는 많이 걷는 사람들인데 신기록갱신 축하효과음을 들은적이 없어서 아무리 신기록을 갱신해도 그렇게 많이 기쁘지 않네요 폰이 진동모드일땐 시도때도없이 소리는 없게 주의하면서 진동으로만 새로운 신기록을 갱신했다고 알려주시기만 한다면 완벽할것 같네요',
#   '2019년 9월 30일',
#   '별표 5개 만점에 2개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   'ㅎㅎ..앱 첨 설치했을 땐 되게 기능은 좋다고 생각했는데 7일 무료체험 이런거 있는지도 잘 몰랐고 구글이 저절로 카드 연결해놔서 앱삭제한지 5개월 됐는데 매달 돈나가고 있었네요,,,^^ 오늘 통장정리하다가 이제라도 알아차려서 다행이긴 한데 굉장히 분하네요ㅠㅠㅠㅠㅠ 하지만 앱이 잘못한것은 없으니 기능은 좋아서 별점 드려요....9월부터 사용해서 거의 2만원 나갔던데.. 기부했다고 생각할게요.. 번창하세요..',
#   '2019년 3월 9일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '제가 운동한 경로,시간,거리,날짜 다 저장할수 있어서 좋아요. 노래가 나와도 음성이 중간중간 시간,거리 말해주는것도 만족해요^^ 잘사용하고 있어요. 단점이라면 지도를 너무 대충 만든거 같은 느낌ㅎ',
#   '2022년 7월 12일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '만보가 그래프로 그려져서 성취욕을 고무시키고 후기를 통해 서로 좋은 이야기를 나눌수 있는점도 좋고 체중을 기록하면 변화를 가르쳐주어서 너무 좋아요 운동프로그램도 있어서 따라하기도 좋고 무척이나 유용한 앱입니다 무궁한 발전을 바랍니다',
#   '2020년 4월 25일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '워치와 호환해서 잘 사용하고 있습니다. 주간 분석까지 해줘서 아무래도 눈으로 직접확인을 할 수 있어 동기부여가 돼 참고해서 더 열심히 걷게되네요~~',
#   '2023년 6월 13일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '실시간으로 걷는 위치를 지도에 표기 해서 얼마만큼 걸었는지 파악하기 쉬움',
#   '2023년 8월 13일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '무료 버전에도 많은 정보를 제공 받을 수 있어서 충분히 만족합니다.',
#   '2023년 7월 4일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '몇일 사용중인데 광고가 자주 나와 아직 편한지 잘 모르겠어요',
#   '2023년 7월 6일',
#   '별표 5개 만점에 3개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '제대로 움직임만큼만 더하지도 덜하지도 않게 계측되는 것 같음 삼성헬스 등은 너무 카운트가 과하게 되는 듯',
#   '2023년 5월 4일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '기능은 괜찮은데 광고가 자주 나오고 도움말도 불친절하고 한국어 설정이면 도움말도 한국어로 나와야할텐데 불편해요. 간거리가 지도로 뜬다고 했는데 지도 어떻게 보는지 몰라서 인터넷 검색해야했어요. 내설정에 무료버전이라고 되어있어서 그냥 쓰는데 7일후에 돈나가면 어이없을것같네요.',
#   '2019년 2월 22일',
#   '별표 5개 만점에 3개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   'ios 때부터 사용하던건데 왜 안드로이드는 사진 첨부가 안될까요. 그리고 고도 높이기도 올라간 높이와 내려온 높이가 누적되어 올라간 높이보다 두배로 나오는데 이번에 S23으로 바꿔서 최적화의 문제인지. 아무튼 안드로이드 버전은 좀 부족하게 느껴지네요.',
#   '2023년 3월 5일',
#   '별표 5개 만점에 3개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '다 좋은데 백업이 안돼서 기기변경을 하거나 어플을 삭제한뒤 다시 깔면 기존 기록들이 연동되지 못하고 모두 사라진다는 단점이 있습니다. 기록 백업만 가능하면 참 좋을텐데 아쉽네요.',
#   '2022년 8월 3일',
#   '별표 5개 만점에 4개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '음...어..괜찮은거 같아요! 추천했는데 그 사람이 좋아하더라고요. 다만 걸음측정이 폰을 흔들면 늘어나서 그부분은 아쉬운데 뭐 대강은 측정하고 교통수단을 이용할때에도 측정이 되어서 허술(?) 하다만 전체적으로는 만족스러워 별점5점 드립니다',
#   '2018년 10월 11일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '매일 운동합니다 너무 좋아용',
#   '2023년 8월 9일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '이틀사용했는데.. gps로 걸을때 지도상 표시되는게 좋아요..실시간이 아닌게 좀 아쉽고요.운동을 다 끝내야 전체 운동과정을 수치로 볼 수 있어 아쉬워요.',
#   '2019년 4월 13일',
#   '별표 5개 만점에 4개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '체계적입니다. 제일 나은 프로그래이라 생각되는군요. 계속 사용할 예정입니다. 다만 걸음폭 조절기능이 없는 것이 . . 실제보다 걸은거리가 짧게 나오는 것 같습니다.',
#   '2022년 6월 10일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '엄청 둔감해요. 민감도를 최대로 높였는데도 왕복 4킬로+집안에서 움직인 걸 900보 정도로밖에 못 측정하네요. 손으로 들고 좌우로 크게 움직이면서 걸어야지만 측정되나봅니다.',
#   '2021년 8월 6일',
#   '별표 5개 만점에 1개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '걸음걸이수가 타 어플에비해 정확한거 같습니다. 보폭을크게하고 빠른걸음을하면 보통걸음과의 차이가 명확합니다. 참 광고없는거 너무 마음에 듭니다',
#   '2021년 5월 24일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '잘 사용하던 앱인데, 요즘 갑자기 거리가 오류 기록됩니다. 6키로 정도 걸었는데 1키로도 안 걸은걸로 기록되네요ㅠㅠ 운동하고 기록이 오류나면 허무해요',
#   '2020년 10월 13일',
#   '별표 5개 만점에 4개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '운동량이 부족해서 운동하고 운동량 기록하려고 다운받긴했는데 키 몸무게 이메일같은 개인정보까지 다 등록해야 쓸수있다니...뭔가 찝찝해서 쓰기싫어서 삭제하려고 합니다. 불필요한 개인정보에 대해서 지나치게 묻지않나 생각 해보시길 바랍니다.',
#   '2018년 11월 22일',
#   '별표 5개 만점에 1개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '매일 매일 운동에 대한 동기 부여도 되고, 잘 사용 중입니다. 회사에서 제공한 손목(?) 밴드랑 동기화를 시킬려고 하는데 그건 잘 안되네요. 매번 핸드폰 들고 운동하는 건 아니라서. 그래도 만족합니다.',
#   '2020년 9월 1일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '걸음, gps기반 거리 측정, 시간 등 다양한 활용이 가능하고 피드를 공유할 수 있다는것도 좋네요. 단 화면 구성이 복잡한 느낌이라 어려워요ㅠ',
#   '2021년 6월 23일',
#   '별표 5개 만점에 4개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '걷기기록도 되고 이동기록도 되서 좋고 음악앱과 같이 작동도 되서 걸으면서 노래듣기도 좋아요 단...배터리 소모는 크네요 2시간 걸으니 방전 ㅜㅜ',
#   '2022년 1월 23일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '거리 정확하고 속도까지 표시되어 좋지만, 탈퇴 안되고 운동할때만 켜고 싶은데 맨날 켜있는게 거슬림. 강제로 껐더니 에러나서 앱 삭제합니다.',
#   '2019년 6월 10일',
#   '별표 5개 만점에 3개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '2년전에 잠깐 쓰고 정기구독도 아닌데 갑자기 결재가 되었어요. 웃긴건 아이디 로그인이 안돼 비번 재설정 하라하고 메일로 변경안내 보낸다고 안내창이 뜨는데 정작 메일은 안옴 어쩌라고? 구글 정기구독 목록에도 없어서.. 이러다 평생 뜯기는거 아닌지 이 정도면 사기입니다',
#   '2022년 4월 18일',
#   '별표 5개 만점에 1개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '지금 사용한지 25일정도 됐는데 좋아요 벌써 주위 2명에게도 추천했어요!! 근데 딱 한번 카운트가 안되는 오류가 난적이 있어요... 제 지인도 걸었는데 집계가 안됐다구 하는데 오류 고쳐주시면 진짜 완벽할것 같아요ㅠㅠㅠㅠㅠㅠㅠ',
#   '2020년 4월 21일',
#   '별표 5개 만점에 4개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '강추합니다. 간편하면서도, 정확하고, 거리와 칼로리, 만보기 시간 등등 꼭 필요한 정보들만 보기 쉽게 표현되어 있어 참 유용합니다.',
#   '2020년 5월 14일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '무료인줄 알았는데 유료네요. 유료인데 결제 동의받는 것도없이 구글자동으로 휙 넘어가네요. 유료취소하는 방법도 없네요. 어플받고 30분쯤 후에, 삭제했는데, 아직 무료 체험7일 지나지 않았어요. 유료 결제 안되도록 해주세요.',
#   '2022년 4월 12일',
#   '별표 5개 만점에 1개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '정말 좋은앱 입니다.제가 자주사용하는 gps기능은 인생을 바꿔주고 있을 만큼요.하지만 한가지 오류가 있는것 같습니다.갑자기 걷지도 않은 500m가 뻥튀기해서 더해져서 평균속도와 소모열량이 거짓으로 더해져 기록됩니다.좀더 정확한 측정을 원하는 저로서는 아쉬울 따름입니다.',
#   '2020년 5월 31일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '보이스 피드백을 할 경우 사용하던 음악 플레이어의 볼륨이 낮아져요. 시스템 자체의 볼륨 게이지는 똑같은데 음악만 작게 나옵니당',
#   '2018년 11월 23일',
#   '별표 5개 만점에 3개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '걸을때마다 걸음걸이몇보 걸었다는 표시가 되어 있으니 좋은것같아요',
#   '2023년 6월 16일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '사용하기도 편하고 운동하는 계기도 되고 좋습니다!',
#   '2023년 6월 18일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '운동에 도움이 많이 되네요. 걷는중에 주기적으로 시간/거리/속도를 알려주어 페이스 조절을 할수있어요~~^^',
#   '2021년 1월 20일',
#   '별표 5개 만점에 5개를 받았습니다.'],
#  ['Pacer 만보기: 걸음수 측정기 및 걷기운동 추적 앱',
#   '편하고 유용해요',
#   '2023년 8월 31일',
#   '별표 5개 만점에 5개를 받았습니다.']]
