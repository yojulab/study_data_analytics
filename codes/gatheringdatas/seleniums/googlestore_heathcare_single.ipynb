# %%
from selenium import webdriver

# %%
# open chrome browser
browser = webdriver.Chrome(executable_path='../../../../chromedriver.exe')

# %%
# url in address window
browser.get('https://play.google.com/store/search?q=%ED%97%AC%EC%8A%A4%EC%BC%80%EC%96%B4%EC%95%B1&c=apps&hl=ko-KR')

# %%
browser.implicitly_wait(10)

# %% [markdown]
# ## 제품 클릭
# - section > div > div > div > div:nth-child(2) > div > div > div

# %%
click_path = 'section > div > div > div > div:nth-child(2) > div > div > div'
browser.find_element_by_css_selector(click_path).click()

# %% [markdown]
# ## 제품 정보
# - 서비스명 tag : div > h1 > span
# - 만든회사명 tag : div.Il7kR > div > div > div > a > span
# - 앱정보 tag : div:nth-child(1) > c-wiz:nth-child(2) > div > section > div

# %%
service_name = browser.find_element_by_css_selector('div > h1 > span').text
company_name = browser.find_element_by_css_selector('div.Il7kR > div > div > div > a > span').text
app_information = browser.find_element_by_css_selector('div:nth-child(1) > c-wiz:nth-child(2) > div > section > div').text

[service_name, company_name, app_information]
# Out:
# ['NH헬스케어',
#  'NH농협생명',
#  '한국인의 건강관리 NH 헬스케어!\n\n지인들과 재밌고 건강하게 즐기는 NH헬스케어만의 새로운 걷기 방법 – 걷기 배틀\n걷기 목표 달성시 지급되는 포인트로 완성하는 온라인 텃밭 – 랜선 텃밭 가꾸기\n\n즐겁고 과학적인 당신만을 위한 건강 솔루션 NH 헬스케어!\n업데이트 날짜\n2023. 7. 21.\n건강/운동']

# %% [markdown]
# ### 리뷰 모두 보기
# - click tag : div:nth-child(5) > div > div > button > span

# %%
import time
time.sleep(2)

# %%
browser.find_element_by_xpath('//*/div/div/button/*[contains(text(), "리뷰")]').click()

# %% [markdown]
# ## 리뷰 내용 가져오기
# - 리뷰 묶음 tag : div.fysCi > div > div:nth-child(2) > div
# - 내용 tag : div.h3YV2d
# - 날짜 tag : header > div.Jx4nYe > span
# - 별점 tag : header > div.Jx4nYe > div

# %%
reviews_bundle = browser.find_elements_by_css_selector('div.fysCi > div > div:nth-child(2) > div')
len(reviews_bundle)
# Out:
# 40

# %%
content = reviews_bundle[0].find_element_by_css_selector('div.h3YV2d').text
date = reviews_bundle[0].find_element_by_css_selector('header > div.Jx4nYe > span').text
stars = reviews_bundle[0].find_element_by_css_selector('header > div.Jx4nYe > div').get_attribute('aria-label')

# %%
[content, date, stars]
# Out:
# ['', '2023년 7월 21일', '별표 5개 만점에 4개를 받았습니다.']

# %% [markdown]
# ## 추가 댓글 가져오기
# - 마지막 내용을 클릭
# - 마지막 화면까지 스크롤링

# %%
reviews_bundle[39].click()

# %%
reviews_bundle = browser.find_elements_by_css_selector('div.fysCi > div > div:nth-child(2) > div')
len(reviews_bundle)
# Out:
# 80

# %%
reviews_bundle[40:]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_90")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_94")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_95")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_97")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_98")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_99")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_100")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_101")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_102")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_103")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_104")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_105")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_106")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_107")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_108")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_109")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_110")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_111")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_112")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_113")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_114")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_115")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_116")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_117")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_118")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_119")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_120")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_121")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_122")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_123")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_124")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_125")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_126")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_127")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_128")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_129")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_130")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_131")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="fa67985a70cf58c3bab47f30a2eca243", element="36C55DCA84F187BB5A688BB2C66FF890_element_132")>]
